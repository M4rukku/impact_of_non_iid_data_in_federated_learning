# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
from visualisation.metric_extraction_tools import get_averaged_metrics_of_run, \
    get_metrics_for_individual_run, plot_all_experiments_in_folder, get_all_experiments_in_folder

content_root = Path(os.getcwd()).parent

# %%
run_non_iid = "checkpoints/InitialFemnistExperiment/FullEvaluationFedAvg_SGD_lr0.0004_nr100_nc3597_le10_i1/FullEvaluationFedAvg_SGD_lr0.0004_nr100_nc3597_le10_i1_run_0"
#run_iid = "checkpoints/InitialFemnistIIDExperiment_Varying_Lr/FullEvaluationFedAvg_SGD_lr0
# .0001_nr100_nc3597_le10_i0/FullEvaluationFedAvg_SGD_lr0.0001_nr100_nc3597_le10_i0_run_0"
#run_iid = "checkpoints/InitialFemnistIIDExperiment_Varying_Lr/FullEvaluationFedAvg_SGD_lr0
# .0005_nr100_nc3597_le10_i1/FullEvaluationFedAvg_SGD_lr0.0005_nr100_nc3597_le10_i1_run_0"
# run_iid = "checkpoints/InitialFemnistIIDExperiment_Varying_Lr/FullEvaluationFedAvg_SGD_lr0.0008_nr100_nc3597_le10_i2/FullEvaluationFedAvg_SGD_lr0.0008_nr100_nc3597_le10_i2_run_0"
run_iid = "checkpoints/InitialFemnistIIDExperiment_Varying_Lr_2/FullEvaluationFedAvg_SGD_lr0.0006_nr100_nc3597_le10_i2/FullEvaluationFedAvg_SGD_lr0.0006_nr100_nc3597_le10_i2_run_0"

centralised_metrics_iid, aggregated_metrics_iid = get_metrics_for_individual_run(content_root, run_iid, 5)
centralised_metrics, aggregated_metrics = get_metrics_for_individual_run(content_root, run_non_iid)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*centralised_metrics_iid["accuracy"], label="acc iid")
ax.plot(*centralised_metrics["accuracy"], label="acc non-iid")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="acc iid")
ax.plot(*aggregated_metrics["accuracy"], label="acc non-iid")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*centralised_metrics_iid["macro_f1_score"], label="macro_f1_score iid")
ax.plot(*centralised_metrics["macro_f1_score"], label="macro_f1_score non-iid")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["loss"], label="macro_f1_score iid")
ax.plot(*aggregated_metrics["loss"], label="macro_f1_score non-iid")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*centralised_metrics["loss"], label="loss centralised")
ax.plot(*aggregated_metrics["loss"], label="loss aggregated")
#ax.set_ylim(4.09, 4.16)
ax.legend()

# %% [markdown]
# Get Averaged Data

# %%
run_iid_path =  "checkpoints/InitialShakespeareIIDExperiments_Varying_LR" \
             "/FullEvaluationFedAvg_SGD_lr0.6_nr8_nc500_le2_i0"
run_non_iid_path =  "checkpoints/InitialShakespeareIIDExperiments_Varying_LR" \
             "/FullEvaluationFedAvg_SGD_lr1.0_nr8_nc500_le2_i2"
#run_non_iid_path = "checkpoints/InitialShakespeareExperiments_lr0.8/FullEvaluationFedAvg_SGD_lr0" \
#                   ".8_nr6_nc799_le2_i0/FullEvaluationFedAvg_SGD_lr0.8_nr6_nc799_le2_i0_run_0"
iid_dir = content_root / run_iid_path
non_iid_dir = content_root / run_non_iid_path

_, aggregated_metrics_iid = get_averaged_metrics_of_run(iid_dir)
_, aggregated_metrics_non_iid = get_averaged_metrics_of_run(non_iid_dir)

fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="acc iid")
ax.plot(*aggregated_metrics_non_iid["accuracy"], label="acc non-iid")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22428/773739757.py in <module>
#       8 non_iid_dir = content_root / run_non_iid_path
#       9
# ---> 10 _, aggregated_metrics_iid = get_averaged_metrics_of_run(iid_dir)
#      11 _, aggregated_metrics_non_iid = get_averaged_metrics_of_run(non_iid_dir)
#      12
#
# I:\Projects\impact_of_non_iid_data_in_federated_learning\visualisation\metric_extraction_tools.py in get_averaged_metrics_of_run(path_to_experiment, multiplicator_centralised)
#      46     files = path_to_experiment.iterdir()
#      47     evaluation_metric_file = \
# ---> 48         list(filter(lambda file: str(file.stem).startswith("avg_evaluation_metrics"), files))[0]
#      49
#      50     data = None
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.2544.0_x64__qbz5n2kfra8p0\lib\pathlib.py in iterdir(self)
# ...

# %%
run_06 = "checkpoints/InitialShakespeareIIDExperiments_Varying_LR/" \
         "FullEvaluationFedAvg_SGD_lr0.8_nr8_nc799_le2_i0"
run_08 = "checkpoints/InitialShakespeareIIDExperiments_Varying_LR/" \
         "FullEvaluationFedAvg_SGD_lr1.0_nr8_nc799_le2_i1"
run_10 = "checkpoints/InitialShakespeareIIDExperiments_Varying_LR/" \
         "FullEvaluationFedAvg_SGD_lr1.2_nr8_nc799_le2_i2"
run001 = "checkpoints/InitialShakespeareExperiments/FullEvaluationFedAvg_SGD_lr0.01_nr8_nc799_le2_i1"
cm08, am08 = get_averaged_metrics_of_run(content_root / run_06, 2)
cm10, am10 = get_averaged_metrics_of_run(content_root / run_08, 2)
#cm12, am12 = get_averaged_metrics_of_run(content_root / run_10, 2)
_, am001 = get_averaged_metrics_of_run(content_root / run001)

fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*cm08["accuracy"], label="LR 0.6")
ax.plot(*cm10["accuracy"], label="LR 0.8")
#ax.plot(*am10["accuracy"], label="LR 1.0")
ax.plot(*am001["accuracy"], label="LR 0.001")
ax.legend()

# %%
fed_adagrad = "checkpoints/Celeba_Varying_Optimisers_Experiment_HP/FullEval_FedAdagrad_SGD_lr0.001_nr100_nc1000_le10_i1"
fed_adam = "checkpoints/Celeba_Varying_Optimisers_Experiment_HP/FullEval_FedAdam_SGD_lr0.001_nr100_nc1000_le10_i2"
fed_avg = "checkpoints/Celeba_Varying_Optimisers_Experiment_HP/FullEval_FedAvg_SGD_lr0.001_nr100_nc1000_le10_i0"
fed_yogi = "checkpoints/Celeba_Varying_Optimisers_Experiment_HP/FullEval_FedYogi_SGD_lr0.001_nr100_nc1000_le10_i3"

cm_avg, am_avg = get_averaged_metrics_of_run(content_root / fed_avg)
cm_adam, am_adam = get_averaged_metrics_of_run(content_root / fed_adam)
cm_adagrad, am_adagrad = get_averaged_metrics_of_run(content_root / fed_adagrad)
cm_yogi, am_yogi = get_averaged_metrics_of_run(content_root / fed_yogi)

fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*cm_avg["accuracy"], label="FedAvg")
ax.plot(*cm_adam["accuracy"], label="FedAdam")
ax.plot(*cm_adagrad["accuracy"], label="FedAdagrad")
ax.plot(*cm_yogi["accuracy"], label="FedYogi")
ax.legend()

# %%
plot_all_experiments_in_folder(content_root /"checkpoints/Celeba_Varying_Optimisers_Experiment_HP",
                               naming_keys=["strategy_name", "optimizer_name"])

# %%
av_run = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAvg_SGD_lr0.001_nr500_nc1000_le1_i0"
ad_run_instance = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1_run_0"


cm_adagrad, aggregated_metrics = get_metrics_for_individual_run(content_root, ad_run_instance, 5)
cm_fedavg, aggregated_metrics_iid = get_averaged_metrics_of_run(content_root / av_run)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
av_run = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAvg_SGD_lr0.001_nr500_nc1000_le1_i0"
ad_run_instance = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1_run_0"


cm_adagrad, aggregated_metrics = get_metrics_for_individual_run(content_root, ad_run_instance, 5)
cm_fedavg, aggregated_metrics_iid = get_averaged_metrics_of_run(content_root / av_run)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
av_run = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAvg_SGD_lr0.001_nr500_nc1000_le1_i0"
ad_run_instance = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1_run_0"


cm_adagrad, aggregated_metrics = get_metrics_for_individual_run(content_root, ad_run_instance, 5)
cm_fedavg, aggregated_metrics_iid = get_averaged_metrics_of_run(content_root / av_run)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()

# %%
av_run = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAvg_SGD_lr0.001_nr500_nc1000_le1_i0"
ad_run_instance = "checkpoints/Celeba_Varying_Optimisers_Type_1_Experiment/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1/FullEval_FedAdagrad_SGD_lr0.001_nr500_nc1000_le1_i1_run_0"


cm_adagrad, aggregated_metrics = get_metrics_for_individual_run(content_root, ad_run_instance, 5)
cm_fedavg, aggregated_metrics_iid = get_averaged_metrics_of_run(content_root / av_run)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2))
ax.plot(*aggregated_metrics_iid["accuracy"], label="FedAvg")
ax.plot(*aggregated_metrics["accuracy"], label="FedAdagrad")
ax.legend()
